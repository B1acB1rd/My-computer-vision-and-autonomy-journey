# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
refFilename = r"C:\Users\B1ACB1RD\Desktop\01.1 Code - Modern Computer Vision_05_06_2022\Modern Computer Vision\My-computer-vision-and-autonomy-journey\Homograpphy computated\images3.png"
im1 = cv2.imread(refFilename, cv2.IMREAD_COLOR)
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)
defFilename = r"C:\Users\B1ACB1RD\Desktop\01.1 Code - Modern Computer Vision_05_06_2022\Modern Computer Vision\My-computer-vision-and-autonomy-journey\Homograpphy computated\images2.png"
im2 = cv2.imread(defFilename, cv2.IMREAD_COLOR)
im2 = cv2.cvtColor(im2, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize = [20 ,10]);
plt.subplot(121); plt.axis('off'); plt.imshow(im1); plt.title("First image")
plt.subplot(122); plt.axis('off'); plt.imshow(im2); plt.title("Second image")
# Out:
# Text(0.5, 1.0, 'Second image')
